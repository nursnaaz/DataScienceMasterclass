# %%
import numpy as np

# %%
((-0.36*np.log2(0.36)) - (0.64*np.log2(0.64)))
# Out:
# 0.9426831892554922

# %%
Entropy of Outlook

# %% [markdown]
# ![Screenshot%202023-09-09%20at%209.58.18%20AM.png](attachment:Screenshot%202023-09-09%20at%209.58.18%20AM.png)

# %%
((-(3/5)*np.log2(3/5)) - (2/5*np.log2(2/5)))
# Out:
# 0.9709505944546686

# %%
((-(4/4)*np.log2(4/4)) - (0*np.log2(0)))
# Out:
# /var/folders/cv/kmsppstx0d9281mtbqrrgl6c0000gn/T/ipykernel_52871/2077371371.py:1: RuntimeWarning: divide by zero encountered in log2
#   ((-(4/4)*np.log2(4/4)) - (0*np.log2(0)))
# /var/folders/cv/kmsppstx0d9281mtbqrrgl6c0000gn/T/ipykernel_52871/2077371371.py:1: RuntimeWarning: invalid value encountered in double_scalars
#   ((-(4/4)*np.log2(4/4)) - (0*np.log2(0)))
# nan

# %%
(-(4/4)*np.log2(4/4))
# Out:
# -0.0

# %%
np.log2(0)
# Out:
# /var/folders/cv/kmsppstx0d9281mtbqrrgl6c0000gn/T/ipykernel_52871/2251961259.py:1: RuntimeWarning: divide by zero encountered in log2
#   np.log2(0)
# -inf

# %%
((-(2/5)*np.log2(2/5)) - (3/5*np.log2(3/5)))
# Out:
# 0.9709505944546686
