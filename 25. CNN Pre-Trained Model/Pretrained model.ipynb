# %%
from keras.applications import VGG16
from keras.preprocessing import image

# %%
model = VGG16()
# Out:
# ...
# 553467096/553467096 [==============================] - 64s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
from keras.preprocessing import image
image1 = image.image_utils.load_img('cat.jpeg', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = image.image_utils.load_img('lion.jpeg', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = image.image_utils.load_img('refrig.jpeg', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = image.image_utils.load_img('mountain.jpeg', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = image.image_utils.load_img('refrigrator.jpeg', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = image.image_utils.load_img('69897.png', target_size = (224, 224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
transformedImage = image.image_utils.img_to_array(image1)
print(transformedImage.shape)
# Out:
# (224, 224, 3)

# %%
import numpy as np
transformedImage = np.expand_dims(transformedImage, axis = 0)
transformedImage.shape
# Out:
# (1, 224, 224, 3)

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
transformedImage = preprocess_input(transformedImage)
transformedImage
# Out:
# array([[[[-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          ...,
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619]],
#
#         [[-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          ...,
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619]],
#
#         [[-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          ...,
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619]],
#
#         ...,
#
#         [[-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          [-227.619, -233.558, -227.619],
#          ...,
# ...

# %%
prediction = model.predict(transformedImage)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 446ms/step
# [[3.24069944e-08 1.37901498e-06 4.07133491e-08 1.24588780e-07
#   4.89267086e-06 1.91451795e-06 8.02633622e-07 7.99403040e-07
#   2.61912390e-07 4.31182656e-07 1.61297393e-07 4.05786089e-08
#   1.62429412e-08 1.10950982e-08 5.71403760e-08 1.80518001e-08
#   1.26001879e-07 2.39692412e-07 6.68873554e-07 2.18740315e-08
#   4.34318146e-08 5.76264142e-07 2.12063583e-06 5.27141083e-07
#   2.84338455e-07 3.34976363e-07 5.89259059e-07 1.22030735e-06
#   5.36369441e-07 1.52122126e-07 3.56161571e-08 1.20790219e-06
#   2.91058882e-07 2.68577452e-07 3.33301318e-06 2.44586751e-08
#   2.19135472e-07 1.21091697e-08 8.57287669e-05 3.06779810e-07
#   2.15429213e-06 1.40131988e-07 8.21300887e-07 8.22553119e-08
#   1.68348447e-06 1.37908019e-05 1.25368581e-06 4.82969654e-06
#   7.81654137e-08 5.87271415e-07 6.97163387e-07 2.66481521e-07
#   8.83794584e-08 5.93517200e-07 3.92352467e-06 1.36881079e-06
# ...

# %%
np.argmax(prediction)
# Out:
# 530

# %%
from tensorflow.keras.applications.vgg16 import decode_predictions
predictionLabel = decode_predictions(prediction, top = 1)
predictionLabel
# Out:
# [[('n03196217', 'digital_clock', 0.95040727)]]

# %%
prediction
# Out:
# array([[1.21389667e-06, 1.75133082e-05, 1.00350542e-06, 2.47839739e-06,
#         4.02799742e-05, 2.03040763e-05, 1.68467213e-05, 1.26939522e-05,
#         4.89915146e-06, 7.64537435e-06, 3.48055460e-06, 1.16666740e-06,
#         5.99019870e-07, 4.72666358e-07, 1.90444950e-06, 6.15176361e-07,
#         3.06803940e-06, 4.17880528e-06, 1.28162001e-05, 5.65723212e-07,
#         1.14848353e-06, 1.39723916e-05, 2.65402887e-05, 8.28608518e-06,
#         5.33173534e-06, 5.04359696e-06, 9.67613141e-06, 1.28132306e-05,
#         5.68735459e-06, 3.38499376e-06, 1.03156856e-06, 1.02251988e-05,
#         4.39629366e-06, 5.92584820e-06, 2.10292619e-05, 1.16427213e-06,
#         7.17837156e-06, 7.50826416e-07, 4.07925225e-04, 3.81806194e-06,
#         2.20020847e-05, 2.35931225e-06, 9.00676878e-06, 1.70098485e-06,
#         2.22338567e-05, 1.60890355e-04, 1.43877251e-05, 5.74760306e-05,
#         1.83522934e-06, 1.12672906e-05, 1.53973597e-05, 4.27451823e-06,
# ...

# %%
len(prediction[0])
# Out:
# 1000

# %%
decode_predictions(np.array([[i for i in range(0,1000)]]), top = 1)
# Out:
# [[('n15075141', 'toilet_tissue', 999)]]
