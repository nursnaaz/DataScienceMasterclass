# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#DataSet:   
#https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/code  
#https://www.kaggle.com/code/noordeen/notebookac348e4669

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv('creditcard.csv')

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
data['Class'].value_counts(normalize = 'True')
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(30,30))
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1081

# %%
data.drop_duplicates(inplace = True)

# %%
data['Class'].value_counts(normalize = 'True')
# Out:
# Class
# 0    0.998333
# 1    0.001667
# Name: proportion, dtype: float64

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [283726 rows x 31 columns]

# %%
data.groupby('Class').Time.median().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Class'>

# %%
data.groupby('Class').Amount.mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Class'>

# %%
sns.boxplot(x = 'Class', y = 'Amount', data = data)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
X = data.drop(columns = ['Class'])
y = data['Class']

# %%
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.2, random_state=12)

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(train_X,train_y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
text_representation = tree.export_text(model_dt)
print(text_representation)
# Out:
# |--- feature_17 <= -2.75
# |   |--- feature_12 <= -2.18
# |   |   |--- feature_26 <= -0.26
# |   |   |   |--- feature_27 <= 1.07
# |   |   |   |   |--- feature_14 <= -2.88
# |   |   |   |   |   |--- feature_4 <= -0.90
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_4 >  -0.90
# |   |   |   |   |   |   |--- feature_26 <= -0.27
# |   |   |   |   |   |   |   |--- feature_19 <= 2.54
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_19 >  2.54
# |   |   |   |   |   |   |   |   |--- feature_26 <= -0.35
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_26 >  -0.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_26 >  -0.27
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_14 >  -2.88
# |   |   |   |   |   |--- feature_14 <= -0.72
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_14 >  -0.72
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_27 >  1.07
# |   |   |   |   |--- feature_6 <= -4.02
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_6 >  -4.02
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_26 >  -0.26
# |   |   |   |--- feature_14 <= -3.71
# |   |   |   |   |--- feature_4 <= -0.30
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_4 >  -0.30
# |   |   |   |   |   |--- feature_4 <= 1.72
# |   |   |   |   |   |   |--- feature_28 <= 0.30
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_28 >  0.30
# |   |   |   |   |   |   |   |--- feature_20 <= 0.22
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_20 >  0.22
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_4 >  1.72
# |   |   |   |   |   |   |--- feature_25 <= 1.07
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_25 >  1.07
# |   |   |   |   |   |   |   |--- feature_23 <= -0.36
# |   |   |   |   |   |   |   |   |--- feature_21 <= 1.83
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_21 >  1.83
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_23 >  -0.36
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_14 >  -3.71
# |   |   |   |   |--- feature_13 <= -0.07
# |   |   |   |   |   |--- feature_9 <= -0.86
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_9 >  -0.86
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_13 >  -0.07
# |   |   |   |   |   |--- class: 0
# |   |--- feature_12 >  -2.18
# |   |   |--- feature_7 <= -4.18
# |   |   |   |--- class: 1
# |   |   |--- feature_7 >  -4.18
# |   |   |   |--- class: 0
# |--- feature_17 >  -2.75
# |   |--- feature_14 <= -7.75
# |   |   |--- feature_21 <= -1.28
# |   |   |   |--- class: 0
# |   |   |--- feature_21 >  -1.28
# |   |   |   |--- class: 1
# |   |--- feature_14 >  -7.75
# |   |   |--- feature_14 <= -4.70
# |   |   |   |--- feature_10 <= -1.85
# |   |   |   |   |--- feature_16 <= 2.83
# |   |   |   |   |   |--- feature_6 <= -0.44
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  -0.44
# |   |   |   |   |   |   |--- feature_26 <= -0.08
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_26 >  -0.08
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_16 >  2.83
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_10 >  -1.85
# |   |   |   |   |--- feature_15 <= -1.32
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_15 >  -1.32
# |   |   |   |   |   |--- feature_14 <= -4.73
# |   |   |   |   |   |   |--- feature_25 <= -1.22
# |   |   |   |   |   |   |   |--- feature_4 <= 1.48
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  1.48
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_25 >  -1.22
# |   |   |   |   |   |   |   |--- feature_19 <= 1.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_19 >  1.44
# |   |   |   |   |   |   |   |   |--- feature_24 <= 0.30
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_24 >  0.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_14 >  -4.73
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_14 >  -4.70
# |   |   |   |--- feature_14 <= -1.63
# |   |   |   |   |--- feature_21 <= 9.95
# |   |   |   |   |   |--- feature_14 <= -1.63
# |   |   |   |   |   |   |--- feature_21 <= 6.17
# |   |   |   |   |   |   |   |--- feature_4 <= 1.97
# |   |   |   |   |   |   |   |   |--- feature_14 <= -1.64
# |   |   |   |   |   |   |   |   |   |--- feature_29 <= 480.36
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 166877.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  166877.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_29 >  480.36
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 <= 482.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 >  482.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_14 >  -1.64
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 1.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  1.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  1.97
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.97
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.97
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 725.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  725.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- feature_21 >  6.17
# |   |   |   |   |   |   |   |--- feature_2 <= 2.82
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  2.82
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_14 >  -1.63
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_21 >  9.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_14 >  -1.63
# |   |   |   |   |--- feature_23 <= -15.56
# |   |   |   |   |   |--- feature_23 <= -16.06
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_23 >  -16.06
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_23 >  -15.56
# |   |   |   |   |   |--- feature_26 <= 2.74
# |   |   |   |   |   |   |--- feature_4 <= 5.62
# |   |   |   |   |   |   |   |--- feature_17 <= 2.03
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.66
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.88
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 <= 2.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 >  2.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.88
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.66
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.66
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.66
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_17 >  2.03
# |   |   |   |   |   |   |   |   |--- feature_17 <= 2.03
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_17 >  2.03
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  2.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= -1.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  -1.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_4 >  5.62
# |   |   |   |   |   |   |   |--- feature_4 <= 5.63
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  5.63
# |   |   |   |   |   |   |   |   |--- feature_29 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_29 >  0.03
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_26 >  2.74
# |   |   |   |   |   |   |--- feature_26 <= 2.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_26 >  2.75
# |   |   |   |   |   |   |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model_dt, feature_names=train_X.columns, filled=True)

# %%
train_pred = model_dt.predict(train_X)
print(confusion_matrix(train_y, train_pred))
# Out:
# [[226612      0]
#  [     0    368]]

# %%
print(classification_report(train_y, train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226612
#            1       1.00      1.00      1.00       368
#
#     accuracy                           1.00    226980
#    macro avg       1.00      1.00      1.00    226980
# weighted avg       1.00      1.00      1.00    226980

# %%
test_pred = model_dt.predict(test_X)
print(confusion_matrix(test_y, test_pred))
# Out:
# [[56606    35]
#  [   31    74]]

# %%
print(classification_report(test_y, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56641
#            1       0.68      0.70      0.69       105
#
#     accuracy                           1.00     56746
#    macro avg       0.84      0.85      0.85     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
scale = StandardScaler()
train_X = pd.DataFrame(scale.fit_transform(train_X), columns = train_X.columns)
test_X = pd.DataFrame(scale.fit_transform(test_X), columns = test_X.columns)

# %%
train_X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0       1.325823 -0.299626  0.109438  1.147238 -0.739269  0.088644 -0.578656
# 1      -1.216950  0.468262 -0.178866  0.125889  0.944020 -0.356731 -0.312878
# 2       0.905208  0.065923  0.575493 -0.382807 -0.530561  0.832870 -0.202340
# 3      -1.268474  0.623213  0.177042  0.116134  0.660766 -0.054815 -0.345820
# 4       0.829945  0.009832  0.465268  0.089252 -0.560224  0.465014 -0.375568
# ...          ...       ...       ...       ...       ...       ...       ...
# 226975  0.875845 -0.280256  0.102978  0.944150 -0.864959  0.525288 -0.170466
# 226976 -1.183500  0.790727 -0.759422 -0.773865 -1.756082  0.708885  2.448475
# 226977 -1.150155  0.614899 -0.053756  0.094816  0.133112 -0.395133 -0.690045
# 226978  1.323422 -0.632154  0.962332 -0.599999  1.021879 -0.048072 -0.596398
# 226979  1.134158  0.743625 -0.897725 -2.449267 -1.597854  0.969176  0.165490
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 0       0.631358 -0.143023  0.417942  ... -0.044847 -0.307946 -0.925467
# 1       0.074234  0.021456  0.272416  ... -0.037214  0.219093  0.161411
# 2       0.697354  0.074940 -0.192304  ...  0.024788 -0.447459 -1.157841
# 3       0.079274 -0.046634 -0.204850  ... -0.170823  0.078762  0.225093
# 4       0.704580  0.019702 -0.173746  ... -0.077876 -0.327159 -0.766198
# ...          ...       ...       ...  ...       ...       ...       ...
# 226975  0.534162 -0.074871  0.347688  ...  0.051499 -0.325315 -0.966289
# 226976 -1.223490  0.632638 -1.812829  ... -0.225582 -0.357925 -0.734206
# 226977  0.051691 -0.093157  0.081891  ... -0.133728 -0.027880 -0.041804
# 226978  0.194205  0.483740 -0.217610  ... -0.271530  0.260797  0.918162
# 226979  0.907701 -0.183007  0.987906  ...  0.545542  0.842385  1.911245
#
#              V23       V24       V25       V26       V27       V28    Amount
# 0       0.158960 -0.014483 -1.084008  0.226231 -0.319059 -0.247328 -0.165610
# 1      -0.280984  0.042002  0.911417 -0.535328 -0.018147  0.113962  0.226422
# 2       0.058714  0.129826 -0.780562  0.257091  0.543734  0.206601 -0.339996
# 3      -0.239821  0.017622  1.331002 -0.673741  0.017008  0.018581 -0.334431
# 4       0.031074 -0.805947 -0.961169  0.317834  0.614770  0.244191 -0.347633
# ...          ...       ...       ...       ...       ...       ...       ...
# 226975  0.144308  0.725033 -1.076411  0.161234 -0.286826 -0.200974 -0.222439
# 226976 -0.021164  1.621397  1.041623 -0.399116  0.073021  0.048954 -0.246486
# 226977 -0.126617  1.022842  0.874776  2.202312 -0.273733 -0.042679 -0.265091
# 226978 -0.055497 -0.035025  0.126596 -0.776227 -0.614386  0.185560 -0.230116
# 226979 -0.894010 -1.354329  1.453122 -0.690501 -0.141677 -0.144357  1.021982
#
# [226980 rows x 30 columns]

# %%
def model_result(model_dt, train_X, test_X, train_y, test_y):
    model_dt.fit(train_X,train_y)
    train_pred = model_dt.predict(train_X)
    print('Train Confusion Matrix')
    print(confusion_matrix(train_y, train_pred))
    print('Test Confusion Matrix')
    test_pred = model_dt.predict(test_X)
    print(confusion_matrix(test_y, test_pred))
    print(classification_report(train_y, train_pred))
    print(classification_report(test_y, test_pred))

# %%
model_dt_scaled = DecisionTreeClassifier()

model_result(model_dt_scaled, train_X, test_X, train_y, test_y)
# Out:
# Train Confusion Matrix
# [[226612      0]
#  [     0    368]]
# Test Confusion Matrix
# [[56606    35]
#  [   32    73]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226612
#            1       1.00      1.00      1.00       368
#
#     accuracy                           1.00    226980
#    macro avg       1.00      1.00      1.00    226980
# weighted avg       1.00      1.00      1.00    226980
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56641
#            1       0.68      0.70      0.69       105
#
#     accuracy                           1.00     56746
#    macro avg       0.84      0.85      0.84     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
sample = RandomUnderSampler()
train_X_sample, train_y_sample = sample.fit_resample(train_X, train_y)

# %%
plt.figure(figsize=(30,30))
sns.heatmap(pd.concat([train_X_sample, train_y_sample], axis  =1).corr(), annot = True)
# Out:
# <Axes: >

# %%
model_dt_scaled = DecisionTreeClassifier()

model_result(model_dt_scaled, train_X_sample, test_X, train_y_sample, test_y)
# Out:
# Train Confusion Matrix
# [[368   0]
#  [  0 368]]
# Test Confusion Matrix
# [[52297  4344]
#  [    9    96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       368
#            1       1.00      1.00      1.00       368
#
#     accuracy                           1.00       736
#    macro avg       1.00      1.00      1.00       736
# weighted avg       1.00      1.00      1.00       736
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     56641
#            1       0.02      0.91      0.04       105
#
#     accuracy                           0.92     56746
#    macro avg       0.51      0.92      0.50     56746
# weighted avg       1.00      0.92      0.96     56746

# %%
sample = RandomOverSampler()
train_X_over_sample, train_y_over_sample = sample.fit_resample(train_X, train_y)

# %%
model_dt_scaled = DecisionTreeClassifier()

model_result(model_dt_scaled, train_X_over_sample, test_X, train_y_over_sample, test_y)
# Out:
# Train Confusion Matrix
# [[226612      0]
#  [     0 226612]]
# Test Confusion Matrix
# [[56622    19]
#  [   25    80]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226612
#            1       1.00      1.00      1.00    226612
#
#     accuracy                           1.00    453224
#    macro avg       1.00      1.00      1.00    453224
# weighted avg       1.00      1.00      1.00    453224
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56641
#            1       0.81      0.76      0.78       105
#
#     accuracy                           1.00     56746
#    macro avg       0.90      0.88      0.89     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
train_X_sample, test_X, train_y_sample, test_y

# %%
test_X.to_csv("data_test.csv", index = False)

# %%
import mlflow

# %%
experiment = mlflow.set_experiment("CreditCard_Fraud_Detection_Random")
# Out:
# 2023/12/09 09:53:53 INFO mlflow.tracking.fluent: Experiment with name 'CreditCard_Fraud_Detection_Random' does not exist. Creating a new experiment.

# %%
experiment.experiment_id
# Out:
# '210851045126590253'

# %%
n_estimator = [20,30,50,100]
max_depth = [1,2,3,4,5]

# %%
for estimator in n_estimator:
    for depth in max_depth:
        with mlflow.start_run(experiment_id= experiment.experiment_id):
            model = RandomForestClassifier(n_estimators=estimator, max_depth=depth)
            model.fit(train_X_sample, train_y_sample)
            pred = model.predict(test_X)
            accuracy = accuracy_score(test_y,pred)
            mlflow.log_param("n_estimator", estimator)
            mlflow.log_param("max_depth", depth)
            mlflow.log_metric("Accuracy", accuracy)
            mlflow.log_text("Author","Noordeen")
            mlflow.sklearn.log_model(model,"RandomForestModel")

# %%
# !mlflow ui
# Out:
# [2023-12-09 09:58:33 +0400] [84276] [INFO] Starting gunicorn 21.2.0
# [2023-12-09 09:58:33 +0400] [84276] [INFO] Listening at: http://127.0.0.1:5000 (84276)
# [2023-12-09 09:58:33 +0400] [84276] [INFO] Using worker: sync
# [2023-12-09 09:58:33 +0400] [84277] [INFO] Booting worker with pid: 84277
# [2023-12-09 09:58:33 +0400] [84278] [INFO] Booting worker with pid: 84278
# [2023-12-09 09:58:33 +0400] [84279] [INFO] Booting worker with pid: 84279
# [2023-12-09 09:58:33 +0400] [84280] [INFO] Booting worker with pid: 84280
# ^C
# [2023-12-09 09:59:22 +0400] [84276] [INFO] Handling signal: int
# [2023-12-09 09:59:22 +0400] [84278] [INFO] Worker exiting (pid: 84278)
# [2023-12-09 09:59:22 +0400] [84279] [INFO] Worker exiting (pid: 84279)
# [2023-12-09 09:59:22 +0400] [84280] [INFO] Worker exiting (pid: 84280)
# [2023-12-09 09:59:22 +0400] [84277] [INFO] Worker exiting (pid: 84277)

# %%
from pycaret.classification import *

# %%
train_X_sample = train_X_sample.reset_index().drop(columns = 'index')
train_y_sample = train_y_sample.reset_index().drop(columns = 'index')

# %%
data_preprocessed = pd.concat([train_X_sample,train_y_sample], axis = 1)

# %%
data_preprocessed.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
clf = setup(data = data_preprocessed, target='Class', log_experiment=True, experiment_name= 'Pycaret_Experiement')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 clf = setup(data = data_preprocessed, target='Class', log_experiment=True, experiment_name= 'Pycaret_Experiement')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/classification/functional.py:595, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     593 exp = _EXPERIMENT_CLASS()
#     594 set_current_experiment(exp)
# --> 595 return exp.setup(
#     596     data=data,
#     597     data_func=data_func,
#     598     target=target,
#     599     index=index,
#     600     train_size=train_size,
#     601     test_data=test_data,
#     602     ordinal_features=ordinal_features,
#     603     numeric_features=numeric_features,
#     604     categorical_features=categorical_features,
#     605     date_features=date_features,
#     606     text_features=text_features,
#     607     ignore_features=ignore_features,
#     608     keep_features=keep_features,
#     609     preprocess=preprocess,
#     610     create_date_columns=create_date_columns,
#     611     imputation_type=imputation_type,
#     612     numeric_imputation=numeric_imputation,
#     613     categorical_imputation=categorical_imputation,
#     614     iterative_imputation_iters=iterative_imputation_iters,
#     615     numeric_iterative_imputer=numeric_iterative_imputer,
#     616     categorical_iterative_imputer=categorical_iterative_imputer,
#     617     text_features_method=text_features_method,
#     618     max_encoding_ohe=max_encoding_ohe,
#     619     encoding_method=encoding_method,
#     620     rare_to_value=rare_to_value,
#     621     rare_value=rare_value,
#     622     polynomial_features=polynomial_features,
#     623     polynomial_degree=polynomial_degree,
#     624     low_variance_threshold=low_variance_threshold,
#     625     group_features=group_features,
#     626     drop_groups=drop_groups,
#     627     remove_multicollinearity=remove_multicollinearity,
#     628     multicollinearity_threshold=multicollinearity_threshold,
#     629     bin_numeric_features=bin_numeric_features,
#     630     remove_outliers=remove_outliers,
#     631     outliers_method=outliers_method,
#     632     outliers_threshold=outliers_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     transformation=transformation,
#     636     transformation_method=transformation_method,
#     637     normalize=normalize,
#     638     normalize_method=normalize_method,
#     639     pca=pca,
#     640     pca_method=pca_method,
#     641     pca_components=pca_components,
#     642     feature_selection=feature_selection,
#     643     feature_selection_method=feature_selection_method,
#     644     feature_selection_estimator=feature_selection_estimator,
#     645     n_features_to_select=n_features_to_select,
#     646     custom_pipeline=custom_pipeline,
#     647     custom_pipeline_position=custom_pipeline_position,
#     648     data_split_shuffle=data_split_shuffle,
#     649     data_split_stratify=data_split_stratify,
#     650     fold_strategy=fold_strategy,
#     651     fold=fold,
#     652     fold_shuffle=fold_shuffle,
#     653     fold_groups=fold_groups,
#     654     n_jobs=n_jobs,
#     655     use_gpu=use_gpu,
#     656     html=html,
#     657     session_id=session_id,
#     658     system_log=system_log,
#     659     log_experiment=log_experiment,
#     660     experiment_name=experiment_name,
#     661     experiment_custom_tags=experiment_custom_tags,
#     662     log_plots=log_plots,
#     663     log_profile=log_profile,
#     664     log_data=log_data,
#     665     verbose=verbose,
#     666     memory=memory,
#     667     profile=profile,
#     668     profile_kwargs=profile_kwargs,
#     669 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/classification/oop.py:715, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     712 self.fold_shuffle_param = fold_shuffle
#     713 self.fold_groups_param = fold_groups
# --> 715 self._initialize_setup(
#     716     n_jobs=n_jobs,
#     717     use_gpu=use_gpu,
#     718     html=html,
#     719     session_id=session_id,
#     720     system_log=system_log,
#     721     log_experiment=log_experiment,
#     722     experiment_name=experiment_name,
#     723     memory=memory,
#     724     verbose=verbose,
#     725 )
#     727 # Prepare experiment specific params ======================= >>
#     729 self.log_plots_param = log_plots
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:328, in _TabularExperiment._initialize_setup(self, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, memory, verbose)
#     324 self.logger.info(f"self.USI: {self.USI}")
#     326 self.logger.info(f"self._variable_keys: {self._variable_keys}")
# --> 328 self._check_environment()
#     330 # Set up GPU usage ========================================= >>
#     332 if self.gpu_param != "force" and type(self.gpu_param) is not bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/pycaret_experiment.py:121, in _PyCaretExperiment._check_environment(self)
#     118 from pycaret.utils._show_versions import show_versions
#     120 self.logger.info("Checking libraries")
# --> 121 self.logger.info(show_versions(logger=self.logger))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/_show_versions.py:165, in show_versions(optional, logger)
#     162     print_func("{k:>10}: {stat}".format(k=k, stat=stat))  # noqa: T001
#     164 print_func(f"{prefix}PyCaret required dependencies:")  # noqa: T001
# --> 165 optional_deps_info = _get_deps_info(logger=logger)
#     166 for k, stat in optional_deps_info.items():
#     167     print_func("{k:>20}: {stat}".format(k=k, stat=stat))  # noqa: T001
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/_show_versions.py:130, in _get_deps_info(optional, logger)
#     128 for modname in deps:
#     129     try:
# --> 130         ver = get_module_version(modname)
#     131         if not ver:
#     132             ver = "Installed but version unavailable"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/_dependencies.py:81, in get_module_version(modname)
#      79 def get_module_version(modname: str) -> Optional[LooseVersion]:
#      80     """Raises a ValueError if module is not installed"""
# ---> 81     version = _get_module_version(modname)
#      82     if version is False:
#      83         raise ValueError(f"Module '{modname}' is not installed.")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/_dependencies.py:75, in _get_module_version(modname)
#      72 installed_modules = get_installed_modules()
#      73 if modname not in installed_modules:
#      74     # Fallback. This should never happen unless module is not present
# ---> 75     installed_modules[modname] = _try_import_and_get_module_version(modname)
#      76 return installed_modules[modname]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/_dependencies.py:28, in _try_import_and_get_module_version(modname)
#      26 if logger:
#      27     with redirect_output(logger):
# ---> 28         mod = import_module(modname)
#      29 else:
#      30     mod = import_module(modname)
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py:226
#     224     _LIB = Mock(ctypes.CDLL)  # type: ignore
#     225 else:
# --> 226     _LIB = _load_lib()
#     229 _NUMERIC_TYPES = (int, float, bool)
#     230 _ArrayLike = Union[List, np.ndarray, pd_Series]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py:211, in _load_lib()
#     209 """Load LightGBM library."""
#     210 lib_path = find_lib_path()
# --> 211 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     212 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     213 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py:460, in LibraryLoader.LoadLibrary(self, name)
#     459 def LoadLibrary(self, name):
# --> 460     return self._dlltype(name)
#
# File ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py:382, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     379 self._FuncPtr = _FuncPtr
#     381 if handle is None:
# --> 382     self._handle = _dlopen(self._name, mode)
#     383 else:
#     384     self._handle = handle
#
# OSError: dlopen(/Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <3AF1EF0C-311C-31EC-BCE3-679F37ABEE16> /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (3.1.0)
# Requirement already satisfied: ipython>=5.5.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.24,>=1.21 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.21.5)
# Collecting pandas<2.0.0,>=1.3.0 (from pycaret)
#   Downloading pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 6.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2>=1.2 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy~=1.10.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: pyod>=1.0.8 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.6.2)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.1.0)
# Requirement already satisfied: numba>=0.55.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.57.0)
# Requirement already satisfied: requests>=2.27.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: cloudpickle in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.8.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: tbats>=1.1.3 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: wurlitzer in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from deprecation>=2.1.0->pycaret) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.14.0)
# Requirement already satisfied: stack-data in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: typing-extensions in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.5.0)
# Requirement already satisfied: exceptiongroup in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (1.0.4)
# Requirement already satisfied: pexpect>4.3 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: appnope in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (6.0.1)
# Requirement already satisfied: fastjsonschema in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.19.1)
# Requirement already satisfied: jupyter-core in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (5.4.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.14.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.10)
# Requirement already satisfied: trace-updater>=0.0.8 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: tsdownsample==0.1.2 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.0)
# Requirement already satisfied: urllib3 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (68.0.0)
# Requirement already satisfied: six in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2023.11.17)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.0)
# Requirement already satisfied: Werkzeug<3.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: nest-asyncio in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: comm>=0.1.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (8.4.0)
# Requirement already satisfied: pyzmq>=20 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: executing in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index 0.8.56 requires nest-asyncio<2.0.0,>=1.5.8, but you have nest-asyncio 1.5.6 which is incompatible.
# Successfully installed pandas-1.5.3
