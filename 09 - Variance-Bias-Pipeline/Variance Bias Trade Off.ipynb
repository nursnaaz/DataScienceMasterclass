# %% [raw]
# -- So Far what we have Learned
#
# 1. Python
# 2. Pandas
# 3. Statistics
# 4. Probability
# 5. Data Preprocessing
# 6. EDA (Visualization)
# 7. Linear Regression
#    a. Best Fit Line
#    b. Linear Algebra
#    c. Gradient Descent(partial derivatives)
# 8. Model Validation - Error Metrics, Overfitting, Underfitting, Crossvlidation, train test, Variance bias trade off
# 9. Indepth Practical
# 10. Hackathon
# 11. Polynomial Regression (Pracical)
# 12. Regularization (Avoid Overfitting)
#     a. Ridge
#     b. Lasso
#     c. ElasticNet
# 13. Practical Implementation

# %% [raw]
# Variance and Bias Trade off

# %% [markdown]
# ![Screenshot%202023-08-20%20at%209.16.24%20AM.png](attachment:Screenshot%202023-08-20%20at%209.16.24%20AM.png)

# %% [markdown]
# ![Screenshot%202023-08-20%20at%209.17.47%20AM.png](attachment:Screenshot%202023-08-20%20at%209.17.47%20AM.png)

# %% [markdown]
# ![bias-and-variance-in-machine-learning.png](attachment:bias-and-variance-in-machine-learning.png)

# %% [markdown]
# ![bullseye.png](attachment:bullseye.png)
