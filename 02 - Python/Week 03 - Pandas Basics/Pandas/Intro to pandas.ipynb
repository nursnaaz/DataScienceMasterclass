# %%
import pandas as pd

# %%
#Data Loading

# %%
csv,
database,
json,
hdfs,
xml

# %%
https://raw.githubusercontent.com/nas5w/imdb-data/master/reviews.json
https://gist.githubusercontent.com/djangofan/3186223/raw/ee3840f937e745d5683b046a85cc4a0337e18428/test.xml

# %%
ls
# Out:
# Intro to pandas.ipynb  bank-full.csv          bank.csv

# %%
bank = pd.read_csv('bank-full.csv')

# %%
bank
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]

# %%
bank = pd.read_csv('bank.csv')

# %%
data = pd.read_csv('/Users/mohamednoordeenalaudeen/Downloads/bank/bank.csv', sep = ';', names = ['Age', 'Profession', 
                                                                                                 'Marital Staus', 'education', 
                                                                                                 'default', 'balance', 'housing',
                                                                                                 'loan', 'contact', 'day', 'month', 'duration', 
                                                                                                 'campaign', 'pdays',
                                                                                                 'previous', 'poutcome', 'y'],
                  header = 1)

# %%
data = pd.read_csv('bank-full.csv', sep = ';', names = ['Age', 'Profession', 
                                                                                                 'Marital Staus', 'education', 
                                                                                                 'default', 'balance', 'housing',
                                                                                                 'loan', 'contact', 'day', 'month', 'duration', 
                                                                                                 'campaign', 'pdays',
                                                                                                 'previous', 'poutcome', 'y'],
                  header = 1)

# %%
data
# Out:
#       Age     Profession Marital Staus  education default  balance housing  \
# 0      33       services       married  secondary      no     4789     yes
# 1      35     management        single   tertiary      no     1350     yes
# 2      30     management       married   tertiary      no     1476     yes
# 3      59    blue-collar       married  secondary      no        0     yes
# 4      35     management        single   tertiary      no      747      no
# ...   ...            ...           ...        ...     ...      ...     ...
# 4515   33       services       married  secondary      no     -333     yes
# 4516   57  self-employed       married   tertiary     yes    -3313     yes
# 4517   57     technician       married  secondary      no      295      no
# 4518   28    blue-collar       married  secondary      no     1137      no
# 4519   44   entrepreneur        single   tertiary      no     1136     yes
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
DataFrame

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data
# Out:
#       Age     Profession Marital Staus  education  default  balance  housing  \
# 0     age            job       marital  education  default  balance  housing
# 1      30     unemployed       married    primary       no     1787       no
# 2      33       services       married  secondary       no     4789      yes
# 3      35     management        single   tertiary       no     1350      yes
# 4      30     management       married   tertiary       no     1476      yes
# ...   ...            ...           ...        ...      ...      ...      ...
# 4517   33       services       married  secondary       no     -333      yes
# 4518   57  self-employed       married   tertiary      yes    -3313      yes
# 4519   57     technician       married  secondary       no      295       no
# 4520   28    blue-collar       married  secondary       no     1137       no
# 4521   44   entrepreneur        single   tertiary       no     1136      yes
#
# ...

# %%
def test():
    """
    This is a test function. 
    This will print test while calling
    It does not hold any argument
    It does not return anything
    """
    print("test")

# %%
test()
# Out:
# test

# %%
print(test.__doc__)
# Out:
#     This is a test function.
#     This will print test while calling
#     It does not hold any argument
#     It does not return anything

# %%
review  = pd.read_json("https://raw.githubusercontent.com/nas5w/imdb-data/master/reviews.json")

# %%
review
# Out:
#                                                        t  s
# 0      Once again Mr. Costner has dragged out a movie...  0
# 1      This is an example of why the majority of acti...  0
# 2      First of all I hate those moronic rappers, who...  0
# 3      Not even the Beatles could write songs everyon...  0
# 4      Brass pictures (movies is not a fitting word f...  0
# ...                                                  ... ..
# 49995  Seeing as the vote average was pretty low, and...  1
# 49996  The plot had some wretched, unbelievable twist...  1
# 49997  I am amazed at how this movie(and most others ...  1
# 49998  A Christmas Together actually came before my t...  1
# 49999  Working-class romantic drama from director Mar...  1
#
# [50000 rows x 2 columns]

# %%
#https://github.com/nas5w/imdb-data/blob/master/reviews.json

# %%
data_xml = pd.read_xml("test.xml")

# %%
data_xml
# Out:
#       shape  degrees  sides
# 0    square      360    4.0
# 1    circle      360    NaN
# 2  triangle      180    3.0

# %%
pd.read_csv('bank.csv', sep= ';', nrows=10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
data
# Out:
#       Age     Profession Marital Staus  education  default  balance  housing  \
# 0     age            job       marital  education  default  balance  housing
# 1      30     unemployed       married    primary       no     1787       no
# 2      33       services       married  secondary       no     4789      yes
# 3      35     management        single   tertiary       no     1350      yes
# 4      30     management       married   tertiary       no     1476      yes
# ...   ...            ...           ...        ...      ...      ...      ...
# 4517   33       services       married  secondary       no     -333      yes
# 4518   57  self-employed       married   tertiary      yes    -3313      yes
# 4519   57     technician       married  secondary       no      295       no
# 4520   28    blue-collar       married  secondary       no     1137       no
# 4521   44   entrepreneur        single   tertiary       no     1136      yes
#
# ...

# %%
data.shape
# Out:
# (45210, 17)

# %%
data.columns
# Out:
# Index(['Age', 'Profession', 'Marital Staus', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age              float64
# Profession        object
# Marital Staus     object
# education         object
# default           object
# balance          float64
# housing           object
# loan              object
# contact           object
# day                int64
# month             object
# duration           int64
# campaign           int64
# pdays              int64
# previous           int64
# poutcome          object
# y                 object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45210 entries, 0 to 45209
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            45208 non-null  float64
#  1   Profession     45210 non-null  object
#  2   Marital Staus  45210 non-null  object
#  3   education      45210 non-null  object
#  4   default        45209 non-null  object
#  5   balance        45209 non-null  float64
#  6   housing        45210 non-null  object
#  7   loan           45210 non-null  object
#  8   contact        45210 non-null  object
#  9   day            45210 non-null  int64
#  10  month          45210 non-null  object
#  11  duration       45210 non-null  int64
#  12  campaign       45210 non-null  int64
#  13  pdays          45210 non-null  int64
#  14  previous       45210 non-null  int64
#  15  poutcome       45210 non-null  object
#  16  y              45210 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# Age              2
# Profession       0
# Marital Staus    0
# education        0
# default          1
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
data.describe()
# Out:
#                 Age        balance           day      duration      campaign  \
# count  45208.000000   45209.000000  45210.000000  45210.000000  45210.000000
# mean      40.936029    1362.269659     15.806658    258.163017      2.763880
# std       10.618620    3044.829323      8.322413    257.530660      3.098044
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45210.000000  45210.000000
# mean      40.198739      0.580336
# std      100.129666      2.303465
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
data.describe(include = 'all')
# Out:
#                  Age   Profession Marital Staus  education default  \
# count   45208.000000        45210         45210      45210   45209
# unique           NaN           12             3          4       2
# top              NaN  blue-collar       married  secondary      no
# freq             NaN         9732         27213      23202   44394
# mean       40.936029          NaN           NaN        NaN     NaN
# std        10.618620          NaN           NaN        NaN     NaN
# min        18.000000          NaN           NaN        NaN     NaN
# 25%        33.000000          NaN           NaN        NaN     NaN
# 50%        39.000000          NaN           NaN        NaN     NaN
# 75%        48.000000          NaN           NaN        NaN     NaN
# max        95.000000          NaN           NaN        NaN     NaN
#
#               balance housing   loan   contact           day  month  \
# count    45209.000000   45210  45210     45210  45210.000000  45210
# ...

# %%
data['Profession'].unique()
# Out:
# array(['technician', 'entrepreneur', 'blue-collar', 'unknown',
#        'management', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data['Marital Staus'].unique()
# Out:
# array(['single', 'married', 'divorced'], dtype=object)

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0       unknown        single    unknown      no      1.0      no
# 4      35.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data.isna().sum()
# Out:
# Age              2
# Profession       0
# Marital Staus    0
# education        0
# default          1
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
1. Ignore - Drop the  whole row
2. Replace the missing data with a following statistical behavoir

# %%
data of the 10th class student

age mark city
15  450 chennai
16   ?  madurai  ->
15  430 chennai
17  230 chennai
15  150 chennai
?   440 chennai   -> 15.3


find the Statistical behaviour of the age column

# %%
Mean of age - 15.3
Median of age - 15

# %%
(15+15+16)/3
# Out:
# 15.333333333333334

# %%
Mean of mark - 340
Median of mark -  430
# Out:
#   File "/var/folders/cv/kmsppstx0d9281mtbqrrgl6c0000gn/T/ipykernel_56832/2950942815.py", line 1
#     Mean of mark -
#          ^
# SyntaxError: invalid syntax

# %%
(450+430+230+150+440)/5
# Out:
# 340.0

# %%
150, 230, 430, 440, 450

# %%
mean will be pulled by an outlier

# %%
name salary
a.     20000
b.     40000
c.     30000
d.     45000
e.     40000
f.     43000
g.       ?   (mean)
mukesh ambani.   9000000000000000000     outlier


g. person -> 900000000000003242424

# %%
When ever you have an outlier never go for mean
When ever you have an outlier go for median

# %%
Outlier  ->

# %%
If there is an outlier the mean and median is going to be far apart
If there is no outlier the mean and median is going to be very closer

# %%
data.isna().sum()
# Out:
# Age              2
# Profession       0
# Marital Staus    0
# education        0
# default          1
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
data.shape
# Out:
# (45210, 17)

# %%
data.dropna(subset = ['Age'], inplace = True)
#or
#data = data.dropna(subset = ['Age'])

# %%
data.dropna()
#or
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0       unknown        single    unknown      no      1.0      no
# 4      35.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data.isna().sum()
# Out:
# Age              0
# Profession       0
# Marital Staus    0
# education        0
# default          1
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
data['Age']
# Out:
# 0        44.0
# 1        33.0
# 2        47.0
# 3        33.0
# 4        35.0
#          ...
# 45205    51.0
# 45206    71.0
# 45207    72.0
# 45208    57.0
# 45209    37.0
# Name: Age, Length: 45208, dtype: float64

# %%
data.loc[4,'Age']
# Out:
# 35.0

# %%
data.iloc[4,0]
# Out:
# 35.0

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0       unknown        single    unknown      no      1.0      no
# 4      35.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data.iloc[3, 2] #=> 3rd index row and 2nd index column -> Single
# Out:
# 'single'

# %%
data.loc[3,'y']
# Out:
# 'no'

# %%
#Slicing
data.iloc[3:5, 2:4]
# Out:
#   Marital Staus education
# 3        single   unknown
# 4       married  tertiary

# %%
data.loc[3:5, 'balance': 'poutcome']
# Out:
#    balance housing loan  contact  day month  duration  campaign  pdays  \
# 3      1.0      no   no  unknown    5   may       198         1     -1
# 4    231.0     yes   no  unknown    5   may       139         1     -1
#
#    previous poutcome
# 3         0  unknown
# 4         0  unknown

# %%
data.loc[3:5, 'balance': ]
# Out:
#    balance housing loan  contact  day month  duration  campaign  pdays  \
# 3      1.0      no   no  unknown    5   may       198         1     -1
# 4    231.0     yes   no  unknown    5   may       139         1     -1
#
#    previous poutcome   y
# 3         0  unknown  no
# 4         0  unknown  no

# %%
data.loc[3:5, : 'poutcome']
# Out:
#     Age  Profession Marital Staus education default  balance housing loan  \
# 3  33.0     unknown        single   unknown      no      1.0      no   no
# 4  35.0  management       married  tertiary      no    231.0     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 3  unknown    5   may       198         1     -1         0  unknown
# 4  unknown    5   may       139         1     -1         0  unknown

# %%
data.iloc[3:5, 15]
# Out:
# 3    unknown
# 4    unknown
# Name: poutcome, dtype: object

# %%
data.iloc[3:5, -5:-1]
# Out:
#    campaign  pdays  previous poutcome
# 3         1     -1         0  unknown
# 4         1     -1         0  unknown

# %%
data.iloc[3:5, -5:]
# Out:
#    campaign  pdays  previous poutcome   y
# 3         1     -1         0  unknown  no
# 4         1     -1         0  unknown  no

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0       unknown        single    unknown      no      1.0      no
# 4      35.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data.loc[4,'Age']
# Out:
# 35.0

# %%
data.loc[4,'Age'] = 45

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0       unknown        single    unknown      no      1.0      no
# 4      45.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data['Profession'].unique()
# Out:
# array(['technician', 'entrepreneur', 'blue-collar', 'unknown',
#        'management', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
#Replace -> 'unknown' -> 'not given'

# %%
data[data['Profession'] == 'unknown']
# Out:
#         Age Profession Marital Staus education default  balance housing loan  \
# 3      33.0    unknown        single   unknown      no      1.0      no   no
# 215    47.0    unknown       married   unknown      no     28.0      no   no
# 353    59.0    unknown      divorced   unknown      no     27.0      no   no
# 875    37.0    unknown        single   unknown      no    414.0     yes   no
# 1071   29.0    unknown        single   primary      no     50.0     yes   no
# ...     ...        ...           ...       ...     ...      ...     ...  ...
# 44713  45.0    unknown       married  tertiary      no    406.0      no   no
# 44741  64.0    unknown       married   unknown      no   2799.0      no   no
# 44969  28.0    unknown        single   unknown      no    326.0      no   no
# 45140  77.0    unknown       married   unknown      no    397.0      no   no
# 45185  59.0    unknown       married   unknown      no   1500.0      no   no
#
# ...

# %%
data.loc[data['Profession'] == 'unknown', 'Profession'] = 'Not Given'

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0     Not Given        single    unknown      no      1.0      no
# 4      45.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
data['Profession'].unique()
# Out:
# array(['technician', 'entrepreneur', 'blue-collar', 'Not Given',
#        'management', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data[data['contact']=='unknown']['contact']
# Out:
# 0        unknown
# 1        unknown
# 2        unknown
# 3        unknown
# 4        unknown
#           ...
# 45060    unknown
# 45061    unknown
# 45121    unknown
# 45134    unknown
# 45135    unknown
# Name: contact, Length: 13017, dtype: object

# %%
data.loc[data['contact']=='unknown','contact' ] = 'Not Given'

# %%
data['contact'].unique()
# Out:
# array(['Not Given', 'cellular', 'telephone'], dtype=object)

# %%
data['contact'].value_counts()
# Out:
# cellular     29285
# Not Given    13017
# telephone     2906
# Name: contact, dtype: int64

# %%
data.isna().sum()
# Out:
# Age              0
# Profession       0
# Marital Staus    0
# education        0
# default          1
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
#Replace 'default' missing value with mode
#Replace 'balance' missing value with median

# %%
age
10
20
30
15

# %%
(10+20+30+15)/4
# Out:
# 18.75

# %%
10, 15, 20, 30

# %%
Gender
male
male
female
female
male

#mode -> male

# %%
Gender
male
male
female
female
male
female
?
?

#mode -> female, male

replace - either female or male

# %%
#how many mean can be there for a column? 1
#how many median can be there for a column? 1

# will the mean be there in the data itself? may be 
# will the median be there in the data itself? may be 

# how many mode can be there for a column? atleast one
# will the mode be there in the data itself? yes

# %%
data['Age'].mean()
# Out:
# 40.936250221199785

# %%
data['Age'].median()
# Out:
# 39.0

# %%
data['Age'].mode()
# Out:
# 0    32.0
# Name: Age, dtype: float64

# %%
data['Age'].value_counts()
# Out:
# 32.0    2085
# 31.0    1996
# 33.0    1972
# 34.0    1930
# 35.0    1893
#         ...
# 93.0       2
# 90.0       2
# 95.0       2
# 88.0       2
# 94.0       1
# Name: Age, Length: 77, dtype: int64

# %%
#Replace 'default' missing value with mode
#Replace 'balance' missing value with median

# %%
data['default'].mode()
# Out:
# 0    no
# Name: default, dtype: object

# %%
mode = yes and no

2 missing value

replace with mode

# %%
data['default'].mode()[0]
# Out:
# 'no'

# %%
data['default'].fillna(data['default'].mode()[0], inplace = True)

# %%
data.isna().sum()
# Out:
# Age              0
# Profession       0
# Marital Staus    0
# education        0
# default          0
# balance          1
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
data['balance'].median()
# Out:
# 448.0

# %%
data['balance'].fillna(data['balance'].median(), inplace = True)

# %%
data.isna().sum()
# Out:
# Age              0
# Profession       0
# Marital Staus    0
# education        0
# default          0
# balance          0
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64

# %%
data['y']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 45205    yes
# 45206    yes
# 45207    yes
# 45208     no
# 45209     no
# Name: y, Length: 45208, dtype: object

# %%
Grouping the data based on Profession

# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26769 sha256=60d9b62433e6ad6b612e5d94800ebd5c659464178f470772ddcc80f875ff9185
#   Stored in directory: /Users/mohamednoordeenalaudeen/Library/Caches/pip/wheels/63/e8/ec/75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# ...

# %%
from pandasql import sqldf

# %%
data
# Out:
#         Age    Profession Marital Staus  education default  balance housing  \
# 0      44.0    technician        single  secondary      no     29.0     yes
# 1      33.0  entrepreneur       married  secondary      no      2.0     yes
# 2      47.0   blue-collar       married    unknown      no   1506.0     yes
# 3      33.0     Not Given        single    unknown      no      1.0      no
# 4      45.0    management       married   tertiary      no    231.0     yes
# ...     ...           ...           ...        ...     ...      ...     ...
# 45205  51.0    technician       married   tertiary      no    825.0      no
# 45206  71.0       retired      divorced    primary      no   1729.0      no
# 45207  72.0       retired       married  secondary      no   5715.0      no
# 45208  57.0   blue-collar       married  secondary      no    668.0      no
# 45209  37.0  entrepreneur       married  secondary      no   2971.0      no
#
# ...

# %%
sqldf('select Profession, count(*) from data where y = "yes" group by Profession order by count(*) desc')
# Out:
#        Profession  count(*)
# 0      management      1301
# 1      technician       840
# 2     blue-collar       708
# 3          admin.       631
# 4         retired       516
# 5        services       369
# 6         student       269
# 7      unemployed       202
# 8   self-employed       187
# 9    entrepreneur       123
# 10      housemaid       109
# 11      Not Given        34

# %%
sqldf('select Profession, y, count(*) from data  group by Profession, y order by count(*) desc')
# Out:
#        Profession    y  count(*)
# 0     blue-collar   no      9024
# 1      management   no      8155
# 2      technician   no      6757
# 3          admin.   no      4539
# 4        services   no      3785
# 5         retired   no      1748
# 6   self-employed   no      1392
# 7    entrepreneur   no      1364
# 8      management  yes      1301
# 9       housemaid   no      1131
# 10     unemployed   no      1101
# 11     technician  yes       840
# 12    blue-collar  yes       708
# 13        student   no       669
# 14         admin.  yes       631
# 15        retired  yes       516
# 16       services  yes       369
# 17        student  yes       269
# 18      Not Given   no       254
# 19     unemployed  yes       202
# 20  self-employed  yes       187
# 21   entrepreneur  yes       123
# 22      housemaid  yes       109
# 23      Not Given  yes        34

# %%
data[data['y']=='yes'].groupby('Profession').y.value_counts()
# Out:
# Profession     y
# Not Given      yes      34
# admin.         yes     631
# blue-collar    yes     708
# entrepreneur   yes     123
# housemaid      yes     109
# management     yes    1301
# retired        yes     516
# self-employed  yes     187
# services       yes     369
# student        yes     269
# technician     yes     840
# unemployed     yes     202
# Name: y, dtype: int64

# %%
data['balance'].fillna(data['balance'].median(), inplace = True)

# %%
data_1 = data['balance'].fillna(data['balance'].median())

# %%
del data

# %%
data.groupby('loan').Age.mean()
# Out:
# loan
# no     41.008534
# yes    40.557366
# Name: Age, dtype: float64

# %%
data['loan'].value_counts()
# Out:
# no     37965
# yes     7243
# Name: loan, dtype: int64

# %%
seaborn
matplotlib
bokeh
