# %%
import pandas as pd
import numpy as np

# %%
len(points)
# Out:
# 5

# %%
points
# Out:
# array([[ 4,  4],
#        [10,  7],
#        [ 2,  3],
#        [ 1,  2],
#        [ 6,  5]])

# %%
for i in range(0, len(points)):
    print(points[i,0])
# Out:
# 4
# 10
# 2
# 1
# 6

# %%
for i in range(0, len(points)):
    print(points[i,1])
# Out:
# 4
# 7
# 3
# 2
# 5

# %% [markdown]
# ![Screenshot%202023-07-30%20at%2012.18.42%20PM.png](attachment:Screenshot%202023-07-30%20at%2012.18.42%20PM.png)

# %%
"""
b_gradient =  0 
m_gradient =  0
m_current = 0
b_current = 0
for i in range(0, len(points)):
    N =  len(points)
    x = points[i,0]
    y = points[i,1]
    print("input = x, y : ", x, y)
    b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
    m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    
print(b_gradient,m_gradient)
new_b = b_current - (learning_rate * b_gradient)
new_m = m_current - (learning_rate * m_gradient)
print(new_b, new_m)
"""
# Out:
# input = x, y :  4 4
# input = x, y :  10 7
# input = x, y :  2 3
# input = x, y :  1 2
# input = x, y :  6 5
# -8.4 -49.599999999999994
# 0.008400000000000001 0.0496

# %%
def compute_error_for_line(b,m,points):
    totalError = 0
    N =  len(points)
    for i in range(0, len(points)):
        x = points[i,0]
        y = points[i,1]
        totalError += (y - (m*x +b))**2
    return totalError/N

# %%
def step_gradient(b_current, m_current, points, learning_rate):
    b_gradient =  0 
    m_gradient =  0
    N =  len(points)
    for i in range(0, len(points)):
        x = points[i,0]
        y = points[i,1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learning_rate * b_gradient)
    new_m = m_current - (learning_rate * m_gradient)
    return [new_b,new_m]

# %%
def gradient_descent_run(points, learning_rate, initial_b, initial_m, iteration):
    b = initial_b #0
    m = initial_m #0
    iteration_count = 1
    error_ = []
    for i in range(iteration):
        old_b = b
        old_m = m
        [b,m] = step_gradient(b, m, points, learning_rate)
        error = compute_error_for_line(b,m,points)
        print("Error : ", error)
        error_.append(error)
        #b =  #0
        #m =  #0
        #print(b,m)
        change_b = abs(old_b - b)
        change_m = abs(old_m - m)
        if change_m < 0.00000000000000000001:
            print(iteration_count)
            break
        iteration_count += 1
    return [b, m], error_

# %%
[b, m], error_ = gradient_descent_run(points, learning_rate, initial_b, initial_m, iteration)
# Out:
# Error :  18.150432672
# Error :  16.004982656773755
# Error :  14.125876775954868
# Error :  12.480033525675571
# Error :  11.038480340043787
# Error :  9.775843234290907
# Error :  8.66989983756388
# Error :  7.70118794195501
# Error :  6.852662672291226
# Error :  6.109396237667937
# Error :  5.458314975797468
# Error :  4.887969058161709
# Error :  4.388330799284385
# Error :  3.9506180173050636
# Error :  3.567139334320072
# Error :  3.2311586914284183
# Error :  2.936776691891251
# Error :  2.67882668224355
# Error :  2.4527837408084316
# Error :  2.254684970430616
# Error :  2.081059691371414
# Error :  1.9288683047007225
# Error :  1.795448749253828
# Error :  1.6784696089828295
# Error :  1.5758890446803608
# Error :  1.485918826650654
# Error :  1.406992834757054
# Error :  1.3377394709687522
# Error :  1.2769574984488559
# Error :  1.223594881585046
# Error :  1.1767302542262097
# Error :  1.135556689684759
# Error :  1.0993674866103418
# Error :  1.0675437203505964
# ...

# %%
0.8810075664162591 0.6620338779909843

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#     x  y
# 0   4  4
# 1  10  7
# 2   2  3
# 3   1  2
# 4   6  5

# %%
points = np.array(data)

# %%
points
# Out:
# array([[ 4,  4],
#        [10,  7],
#        [ 2,  3],
#        [ 1,  2],
#        [ 6,  5]])

# %%
learning_rate = 0.001

# %%
initial_b = 0
initial_m = 0
iteration = 1000

# %%
[b, m] = gradient_descent_run(points, learning_rate, initial_b, initial_m, iteration)

# %%
[b, m]
# Out:
# [0.8810075664162591, 0.6620338779909843]

# %%
import seaborn as sns
# Out:
# /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
sns.scatterplot(data['x'], data['y'])
# Out:
# /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
from matplotlib import pyplot as plt
plt.plot(data['x'], (0.6620338779909843 * data['x'] + 0.8810075664162591))
plt.plot(data['x'], (0.7595516482451456 * data['x'] + 0.21504998273518994))
sns.scatterplot(data['x'], data['y'])
# Out:
# /Users/mohamednoordeenalaudeen/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.plot(error_)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(data[['x']], data['y'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.53515625])

# %%
reg.intercept_
# Out:
# 1.7382812499999996

# %%
data[['x']]
# Out:
#     x
# 0   4
# 1  10
# 2   2
# 3   1
# 4   6

# %%
data['x']
# Out:
# 0     4
# 1    10
# 2     2
# 3     1
# 4     6
# Name: x, dtype: int64
